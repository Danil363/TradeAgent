# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

import yfinance as yf
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO
import pandas as pd
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
class TradingEnv(gym.Env):
    metadata = {"render.modes": []}

    def __init__(self, prices, window=24, initial_balance=10000, fee=0.001):
        super().__init__()
        self.prices = np.array(prices, dtype=np.float32).flatten()
        self.window = window
        self.initial_balance = initial_balance
        self.fee = fee

        self.balance = float(initial_balance)
        self.position = 0.0
        self.current_step = window
        self.equity_curve = []

        # 0=HOLD, 1=BUY, 2=SELL
        self.action_space = spaces.Discrete(3)

        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(window + 2,),
            dtype=np.float32
        )

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.balance = float(self.initial_balance)
        self.position = 0.0
        self.current_step = self.window
        self.equity_curve = []

        self.buy_count = 0
        self.sell_count = 0

        obs = self._get_obs()
        info = {}
        return obs, info

    def _get_obs(self):
        window_data = self.prices[self.current_step - self.window:self.current_step]
        obs = np.concatenate([
            np.array(window_data, dtype=np.float32),
            np.array([self.balance, self.position], dtype=np.float32)
        ])
        return obs

    def step(self, action):
        price = self.prices[self.current_step]

        # BUY (100% баланса)
        if action == 1:
            self.buy_count += 1
            if self.balance > 0:
                shares = self.balance / (price * (1 + self.fee))
                self.position += shares
                self.balance -= shares * price * (1 + self.fee)

        # SELL
        elif action == 2:
            self.sell_count += 1
            if self.position > 0:
                self.balance += self.position * price * (1 - self.fee)
                self.position = 0.0

        # Equity
        equity = self.balance + self.position * price
        self.equity_curve.append(equity)

        # Reward: процент изменения капитала
        reward = 0.0
        if len(self.equity_curve) > 1:
            reward = (equity - self.equity_curve[-2]) / self.equity_curve[-2]

        self.current_step += 1
        terminated = self.current_step >= len(self.prices) - 1
        truncated = False

        obs = self._get_obs()
        info = {}
        return obs, reward, terminated, truncated, info

    def get_metrics(self):
        curve = np.array(self.equity_curve, dtype=np.float32)
        final_balance = float(curve[-1])
        total_return = (final_balance - self.initial_balance) / self.initial_balance

        returns = np.diff(curve) / curve[:-1]
        sharpe = (np.mean(returns) / (np.std(returns) + 1e-9)
                  if len(returns) > 1 else 0.0)

        running_max = np.maximum.accumulate(curve)
        dd = (curve - running_max) / running_max
        max_dd = float(np.min(dd))

        return {
            "final_balance": final_balance,
            "total_return": float(total_return),
            "sharpe": float(sharpe),
            "max_drawdown": max_dd
        }

    def get_action_stats(self):
        return {
            "buys": self.buy_count,
            "sells": self.sell_count
        }

# %%
class TradingEnvWithPrediction(gym.Env):
    metadata = {"render.modes": []}

    def __init__(self, prices, predicted_prices=None, window=24, initial_balance=10000, fee=0.001):
        super().__init__()
        self.prices = np.array(prices, dtype=np.float32).flatten()
        self.predicted_prices = (np.array(predicted_prices, dtype=np.float32).flatten()
                                 if predicted_prices is not None else None)
        self.window = window
        self.initial_balance = initial_balance
        self.fee = fee

        self.balance = float(initial_balance)
        self.position = 0.0
        self.current_step = window
        self.equity_curve = []

        self.buy_count = 0
        self.sell_count = 0

        # 0=HOLD, 1=BUY, 2=SELL
        self.action_space = spaces.Discrete(3)

        # Добавляем 1 элемент для предсказанной цены
        obs_dim = window + 2 + (1 if self.predicted_prices is not None else 0)
        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(obs_dim,),
            dtype=np.float32
        )

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.balance = float(self.initial_balance)
        self.position = 0.0
        self.current_step = self.window
        self.equity_curve = []
        self.buy_count = 0
        self.sell_count = 0

        obs = self._get_obs()
        info = {}
        return obs, info

    def _get_obs(self):
        window_data = self.prices[self.current_step - self.window:self.current_step]
        obs = [*window_data, self.balance, self.position]

        # Добавляем предсказанную цену текущего шага
        if self.predicted_prices is not None:
            pred_price = self.predicted_prices[self.current_step]
            obs.append(pred_price)

        return np.array(obs, dtype=np.float32)

    def step(self, action):
        price = self.prices[self.current_step]

        if action == 1:  # BUY
            self.buy_count += 1
            if self.balance > 0:
                shares = self.balance / (price * (1 + self.fee))
                self.position += shares
                self.balance -= shares * price * (1 + self.fee)

        elif action == 2:  # SELL
            self.sell_count += 1
            if self.position > 0:
                self.balance += self.position * price * (1 - self.fee)
                self.position = 0.0

        equity = self.balance + self.position * price
        self.equity_curve.append(equity)

        reward = 0.0
        if len(self.equity_curve) > 1:
            reward = (equity - self.equity_curve[-2]) / self.equity_curve[-2]

        self.current_step += 1
        terminated = self.current_step >= len(self.prices) - 1
        truncated = False

        obs = self._get_obs()
        info = {}
        return obs, reward, terminated, truncated, info

    def get_metrics(self):
        curve = np.array(self.equity_curve, dtype=np.float32)
        final_balance = float(curve[-1])
        total_return = (final_balance - self.initial_balance) / self.initial_balance

        returns = np.diff(curve) / curve[:-1]
        sharpe = (np.mean(returns) / (np.std(returns) + 1e-9)
                  if len(returns) > 1 else 0.0)

        running_max = np.maximum.accumulate(curve)
        dd = (curve - running_max) / running_max
        max_dd = float(np.min(dd))

        return {
            "final_balance": final_balance,
            "total_return": float(total_return),
            "sharpe": float(sharpe),
            "max_drawdown": max_dd
        }

    def get_action_stats(self):
        return {
            "buys": self.buy_count,
            "sells": self.sell_count
        }

# %%
ticker = "BTC-USD"
data = yf.download(ticker, period="2y", interval="1h")
prices = data["Close"].to_numpy().flatten()
print("Размер массива цен:", prices.shape)

# --- Train/Test Split ---
test_size = 60 * 24  # последний месяц
train_prices = prices[500:-test_size]
test_prices = prices[-test_size:]

# --- Окружения ---
window = 24
env_train = TradingEnv(train_prices, window=window, fee=0.000)  # обучение без комиссии
env_test  = TradingEnv(test_prices, window=window, fee=0.001)    # тест с реальной комиссией

check_env(env_train, warn=True)
check_env(env_test, warn=True)

# --- Обучение ---
model = PPO(
    "MlpPolicy",
    env_train,
    verbose=1,
    learning_rate=3e-4,
    batch_size=64,
    n_steps=2048,
    gamma=0.99
)
model.learn(total_timesteps=200_000)

# --- Тест ---
obs, info = env_test.reset()
done = False
while not done:
    action, _ = model.predict(obs)
    obs, reward, done, truncated, info = env_test.step(action)

metrics = env_test.get_metrics()
stats = env_test.get_action_stats()

print("\n=== TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v}")

print("\n=== ACTION STATS ===")
print(f"Buys:  {stats['buys']}")
print(f"Sells: {stats['sells']}")
# Out:
# C:\Users\Данил\AppData\Local\Temp\ipykernel_15032\1912971242.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="2y", interval="1h")
# [*********************100%***********************]  1 of 1 completed
# c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Размер массива цен: (17395,)
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 260  |
# |    iterations      | 1    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011934064 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -8.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00718    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 0.00088     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 204          |
# |    iterations           | 3            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0050097997 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00148     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00125     |
# |    value_loss           | 0.000149     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 4          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01089873 |
# |    clip_fraction        | 0.044      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.277     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0317     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00214   |
# |    value_loss           | 0.000214   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 5           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013812324 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 0.000159    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 6           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010483304 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000644   |
# |    value_loss           | 0.000145    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 7           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007230886 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.00259     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0186     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 0.000183    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 8           |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008120194 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00963    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 9.23e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.54e+04   |
# |    ep_rew_mean          | 0.421      |
# | time/                   |            |
# |    fps                  | 196        |
# |    iterations           | 9          |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01714817 |
# |    clip_fraction        | 0.0885     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0416    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00586   |
# |    value_loss           | 0.000103   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 10          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009004844 |
# |    clip_fraction        | 0.0137      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.00111     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00692     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00036    |
# |    value_loss           | 0.000194    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 11          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014025041 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00332     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 0.000162    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 12          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008244649 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.135      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00705     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 0.000161    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 13          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014999116 |
# |    clip_fraction        | 0.021       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.022      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 0.000202    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.421        |
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 14           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0116706155 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.000945    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0223      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 0.00026      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 15          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008695245 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00931    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 0.000133    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.533       |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 16          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014216073 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00471    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00697    |
# |    value_loss           | 4.72e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.54e+04   |
# |    ep_rew_mean          | 0.533      |
# | time/                   |            |
# |    fps                  | 193        |
# |    iterations           | 17         |
# |    time_elapsed         | 180        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01041635 |
# |    clip_fraction        | 0.031      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.947     |
# |    explained_variance   | 0.00118    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.022      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00142   |
# |    value_loss           | 0.000136   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.54e+04   |
# |    ep_rew_mean          | 0.533      |
# | time/                   |            |
# |    fps                  | 192        |
# |    iterations           | 18         |
# |    time_elapsed         | 191        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00879426 |
# |    clip_fraction        | 0.0317     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.875     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00873    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.001     |
# |    value_loss           | 0.000179   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.533       |
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 19          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007690216 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | -0.0091     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00676    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 0.00021     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.533       |
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 20          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004459653 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.741      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0179      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 9.4e-05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.533        |
# | time/                   |              |
# |    fps                  | 192          |
# |    iterations           | 21           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0022699523 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.697       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00136      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.000211     |
# |    value_loss           | 0.000151     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.533        |
# | time/                   |              |
# |    fps                  | 192          |
# |    iterations           | 22           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0015743102 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.718       |
# |    explained_variance   | 0.00163      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00446      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 9.62e-05     |
# |    value_loss           | 0.000206     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.452        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 23           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0037632394 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.771       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000905    |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 6.08e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.452        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 24           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0056623872 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.832       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00549      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000817    |
# |    value_loss           | 9.06e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.452       |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 25          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.003913126 |
# |    clip_fraction        | 0.0192      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.00277     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 0.000223    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.452       |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 26          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008733653 |
# |    clip_fraction        | 0.0462      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00949     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00327    |
# |    value_loss           | 0.000117    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.452       |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 27          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.003813998 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | 0.0566      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00347    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000384   |
# |    value_loss           | 0.000195    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.452       |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 28          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005417253 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00689     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 0.000123    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.452        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 29           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0028290425 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | -0.0227      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00376     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 0.000125     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.452       |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 30          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004059896 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0063     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 7.15e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.527        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 31           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0031054348 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.607       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0092      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -6.38e-05    |
# |    value_loss           | 5.78e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.527        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 32           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0045306776 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00457     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 0.000121     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.527        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 33           |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0016325886 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.481       |
# |    explained_variance   | 0.00354      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00181      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 0.000201     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.527        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 34           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0011330429 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00245     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 0.000188     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.527        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 35           |
# |    time_elapsed         | 373          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0034627372 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00158     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 0.0001       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.527       |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 36          |
# |    time_elapsed         | 384         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.001277467 |
# |    clip_fraction        | 0.00869     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.431      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00053    |
# |    value_loss           | 0.000133    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.527         |
# | time/                   |               |
# |    fps                  | 191           |
# |    iterations           | 37            |
# |    time_elapsed         | 395           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00033637474 |
# |    clip_fraction        | 0.00962       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.397        |
# |    explained_variance   | -0.0131       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00583      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000363     |
# |    value_loss           | 0.000219      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.492         |
# | time/                   |               |
# |    fps                  | 191           |
# |    iterations           | 38            |
# |    time_elapsed         | 405           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00024123088 |
# |    clip_fraction        | 0.0111        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.435        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00333      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.00036      |
# |    value_loss           | 5.77e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.492        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 39           |
# |    time_elapsed         | 416          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0023632953 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00941     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 0.000108     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.492        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 40           |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0011485226 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.388       |
# |    explained_variance   | 0.0046       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00441     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 0.00021      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.492        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 41           |
# |    time_elapsed         | 437          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0015109635 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.432       |
# |    explained_variance   | -0.0227      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00239     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000462    |
# |    value_loss           | 0.000153     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.492        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 42           |
# |    time_elapsed         | 448          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0016078791 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.427       |
# |    explained_variance   | 0.00748      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0063       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 0.000237     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.492        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 43           |
# |    time_elapsed         | 458          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0028906567 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0149       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000202    |
# |    value_loss           | 0.000202     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.492        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 44           |
# |    time_elapsed         | 470          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0014010558 |
# |    clip_fraction        | 0.00381      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.408       |
# |    explained_variance   | 0.000475     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00364      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.000113     |
# |    value_loss           | 0.00025      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.492        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 45           |
# |    time_elapsed         | 481          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0023839427 |
# |    clip_fraction        | 0.00591      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.389       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00318     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -1.22e-05    |
# |    value_loss           | 0.000139     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.597        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 46           |
# |    time_elapsed         | 491          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0019636923 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.307       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0065       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 6.42e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.597        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 47           |
# |    time_elapsed         | 502          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0010446331 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00172      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000448    |
# |    value_loss           | 0.000216     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.597        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 48           |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0009468389 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.317       |
# |    explained_variance   | 0.00492      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0126      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0002      |
# |    value_loss           | 0.000256     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.597        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 49           |
# |    time_elapsed         | 523          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0010993419 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.346       |
# |    explained_variance   | -0.0193      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00446     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00084     |
# |    value_loss           | 0.00023      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.597        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 50           |
# |    time_elapsed         | 534          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0018832162 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.381       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00625     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 0.000194     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.597        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 51           |
# |    time_elapsed         | 546          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0018046033 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00252      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00078     |
# |    value_loss           | 0.000264     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.597        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 52           |
# |    time_elapsed         | 556          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0010673797 |
# |    clip_fraction        | 0.00552      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.336       |
# |    explained_variance   | 0.00182      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00261     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 2.73e-06     |
# |    value_loss           | 0.000232     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.705        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 53           |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0008674329 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.297       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00318     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00053     |
# |    value_loss           | 7.04e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.705        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 54           |
# |    time_elapsed         | 578          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0017181948 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.313       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00544      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 0.000122     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.705        |
# ...
# |    policy_gradient_loss | -5e-05        |
# |    value_loss           | 0.000224      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.795        |
# | time/                   |              |
# |    fps                  | 190          |
# |    iterations           | 82           |
# |    time_elapsed         | 879          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 6.221782e-05 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0787      |
# |    explained_variance   | -0.003       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00013      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | 0.000133     |
# |    value_loss           | 0.000286     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.796         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 83            |
# |    time_elapsed         | 890           |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 0.00019605769 |
# |    clip_fraction        | 0.00396       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0894       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.55e-05      |
# |    n_updates            | 820           |
# |    policy_gradient_loss | -0.000332     |
# |    value_loss           | 6.88e-05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.796         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 84            |
# |    time_elapsed         | 901           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 0.00048395403 |
# |    clip_fraction        | 0.00898       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0744       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.82e-05      |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -0.000775     |
# |    value_loss           | 7.02e-05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.796         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 85            |
# |    time_elapsed         | 912           |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 0.00026351074 |
# |    clip_fraction        | 0.00269       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.063        |
# |    explained_variance   | 0.00391       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00267       |
# |    n_updates            | 840           |
# |    policy_gradient_loss | -0.000214     |
# |    value_loss           | 0.000256      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.796        |
# | time/                   |              |
# |    fps                  | 190          |
# |    iterations           | 86           |
# |    time_elapsed         | 922          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0002005614 |
# |    clip_fraction        | 0.00605      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0669      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00263     |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.000365    |
# |    value_loss           | 0.000211     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.796         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 87            |
# |    time_elapsed         | 933           |
# |    total_timesteps      | 178176        |
# | train/                  |               |
# |    approx_kl            | 0.00063257664 |
# |    clip_fraction        | 0.00986       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0815       |
# |    explained_variance   | 0.0803        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0025       |
# |    n_updates            | 860           |
# |    policy_gradient_loss | -0.0012       |
# |    value_loss           | 0.00025       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.796         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 88            |
# |    time_elapsed         | 944           |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 0.00028636333 |
# |    clip_fraction        | 0.00742       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0848       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00103       |
# |    n_updates            | 870           |
# |    policy_gradient_loss | -0.000437     |
# |    value_loss           | 0.000174      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.796         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 89            |
# |    time_elapsed         | 954           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 0.00035749588 |
# |    clip_fraction        | 0.00513       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0745       |
# |    explained_variance   | 0.00151       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0001        |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -0.000272     |
# |    value_loss           | 0.000254      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.796         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 90            |
# |    time_elapsed         | 965           |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 0.00012977066 |
# |    clip_fraction        | 0.00474       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0625       |
# |    explained_variance   | -0.00282      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00067       |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -0.00015      |
# |    value_loss           | 0.000145      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.809         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 91            |
# |    time_elapsed         | 976           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.00031669438 |
# |    clip_fraction        | 0.0041        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0572       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00349       |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -0.000175     |
# |    value_loss           | 9.19e-05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.809         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 92            |
# |    time_elapsed         | 986           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 0.00012954653 |
# |    clip_fraction        | 0.00127       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.06         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000261      |
# |    n_updates            | 910           |
# |    policy_gradient_loss | 2.19e-05      |
# |    value_loss           | 0.000156      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.809         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 93            |
# |    time_elapsed         | 997           |
# |    total_timesteps      | 190464        |
# | train/                  |               |
# |    approx_kl            | 0.00018204606 |
# |    clip_fraction        | 0.00332       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0643       |
# |    explained_variance   | 0.00348       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000111      |
# |    n_updates            | 920           |
# |    policy_gradient_loss | -0.000114     |
# |    value_loss           | 0.000287      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.809         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 94            |
# |    time_elapsed         | 1008          |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 0.00023539105 |
# |    clip_fraction        | 0.00146       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0615       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00289      |
# |    n_updates            | 930           |
# |    policy_gradient_loss | 2.34e-05      |
# |    value_loss           | 0.000171      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.809         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 95            |
# |    time_elapsed         | 1018          |
# |    total_timesteps      | 194560        |
# | train/                  |               |
# |    approx_kl            | 0.00026116063 |
# |    clip_fraction        | 0.00298       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0463       |
# |    explained_variance   | 0.0765        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000154      |
# |    n_updates            | 940           |
# |    policy_gradient_loss | -0.000261     |
# |    value_loss           | 0.000246      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.809         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 96            |
# |    time_elapsed         | 1029          |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.00017577628 |
# |    clip_fraction        | 0.00161       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0391       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000123      |
# |    n_updates            | 950           |
# |    policy_gradient_loss | -3.33e-05     |
# |    value_loss           | 0.000197      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.809        |
# | time/                   |              |
# |    fps                  | 190          |
# |    iterations           | 97           |
# |    time_elapsed         | 1040         |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0001145252 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.032       |
# |    explained_variance   | -0.00275     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000126     |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.000179    |
# |    value_loss           | 0.000304     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.857         |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 98            |
# |    time_elapsed         | 1051          |
# |    total_timesteps      | 200704        |
# | train/                  |               |
# |    approx_kl            | 4.1380816e-05 |
# |    clip_fraction        | 0.000635      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0323       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.15e-05      |
# |    n_updates            | 970           |
# |    policy_gradient_loss | -3.37e-05     |
# |    value_loss           | 0.000104      |
# -------------------------------------------
#
# === TEST METRICS ===
# final_balance: 8029.34228515625
# total_return: -0.197065771484375
# sharpe: -0.02380521036684513
# max_drawdown: -0.3481616675853729
#
# === ACTION STATS ===
# Buys:  6
# Sells: 0

# %%
ticker = "TSLA"

# %%
data = yf.download(ticker, period="2y", interval="1h")
prices = data["Close"].to_numpy().flatten()
print("Размер массива цен:", prices.shape)
# Out:
# C:\Users\Данил\AppData\Local\Temp\ipykernel_19164\2673826667.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="2y", interval="1h")
# [*********************100%***********************]  1 of 1 completed
# Размер массива цен: (3494,)

# %%
data = pd.read_csv('data.csv')

# %%
import yfinance as yf
import numpy as np
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env

# --- Загрузка данных ---
# ticker = "APPL"
data = yf.download(ticker, period="2y", interval="1h")
prices = data["Close"].to_numpy().flatten()
print("Размер массива цен:", prices.shape)

# --- Train/Test Split ---
test_size = 30 * 24  # последний месяц
train_prices = prices[500:-test_size]
test_prices = prices[-test_size:]

# --- Окружения ---
window = 40
env_train = TradingEnv(train_prices, window=window, fee=0.000)
env_test  = TradingEnv(test_prices, window=window, fee=0.001)

check_env(env_train, warn=True)
check_env(env_test, warn=True)

# --- Обучение основной модели ---
model = DQN(
    "MlpPolicy",
    env_train,
    verbose=1,
    learning_rate=1e-4,
    buffer_size=50_000,
    batch_size=64,
    gamma=0.99,
    train_freq=4,
    target_update_interval=1000,
)
model.learn(total_timesteps=200_000)

# --- Тест с онлайн-дообучением ---
obs, info = env_test.reset()
done = False
step = 0

while not done:
    # выбираем действие
    action, _ = model.predict(obs, deterministic=False)
    next_obs, reward, done, truncated, info = env_test.step(action)

    # добавляем новый опыт в буфер
    model.replay_buffer.add(obs, next_obs, action, reward, done, infos=[info])

    # дообучаем на новых данных
    model.train(batch_size=64, gradient_steps=1)

    obs = next_obs
    step += 1

    if step % 500 == 0:
        print(f"Онлайн-дообучение — шаг {step}")

# --- Метрики ---
metrics = env_test.get_metrics()
print("\n=== TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v}")
# Out:
# C:\Users\Данил\AppData\Local\Temp\ipykernel_15032\2762601082.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="2y", interval="1h")
# [*********************100%***********************]  1 of 1 completed
# Размер массива цен: (17395,)
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+04 |
# |    ep_rew_mean      | 0.454    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 477      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 64536    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 27.4     |
# |    n_updates        | 16108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+04 |
# |    ep_rew_mean      | 0.535    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 463      |
# |    time_elapsed     | 278      |
# |    total_timesteps  | 129072   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 28.2     |
# |    n_updates        | 32242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+04 |
# |    ep_rew_mean      | 0.518    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 453      |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 193608   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.3     |
# |    n_updates        | 48376    |
# ----------------------------------
# Онлайн-дообучение — шаг 500
#
# === TEST METRICS ===
# final_balance: 7228.2119140625
# total_return: -0.27717880859375
# sharpe: -0.07183929532766342
# max_drawdown: -0.29982611536979675
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env

# --- Загружаем данные ---
data = pd.read_csv('data_.csv')  # предполагается, что есть колонки Close, predicted_close
prices = data['Close'].to_numpy()
pred_prices = data['Predicted_Close'].to_numpy()  # предсказанные цены

# --- Train/Test Split ---
test_size = 30 * 24  # последний месяц
train_prices = prices[500:-test_size]
train_pred   = pred_prices[500:-test_size]

test_prices = prices[-test_size:]
test_pred   = pred_prices[-test_size:]

# --- Окружения ---
window = 60
env_train = TradingEnvWithPrediction(train_prices, predicted_prices=train_pred, window=window, fee=0.000)
env_test  = TradingEnvWithPrediction(test_prices, predicted_prices=test_pred, window=window, fee=0.001)

check_env(env_train, warn=True)
check_env(env_test, warn=True)

# --- Обучение модели ---
model = DQN(
    "MlpPolicy",
    env_train,
    verbose=1,
    learning_rate=1e-4,
    buffer_size=50_000,
    batch_size=64,
    gamma=0.99,
    train_freq=4,
    target_update_interval=1000,
)
model.learn(total_timesteps=200_000)

# --- Тест с онлайн-дообучением ---
obs, info = env_test.reset()
done = False
step = 0

while not done:
    # выбираем действие
    action, _ = model.predict(obs, deterministic=False)
    next_obs, reward, done, truncated, info = env_test.step(action)

    # добавляем новый опыт в буфер
    model.replay_buffer.add(obs, next_obs, action, reward, done, infos=[info])

    # дообучаем на новых данных
    model.train(batch_size=64, gradient_steps=1)

    obs = next_obs
    step += 1

    if step % 500 == 0:
        print(f"Онлайн-дообучение — шаг {step}")

# --- Метрики ---
metrics = env_test.get_metrics()
print("\n=== TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.114    |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 599      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 8848     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.234    |
# |    n_updates        | 2186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.0892   |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 469      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 17696    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.264    |
# |    n_updates        | 4398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.114    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 453      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 26544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.289    |
# |    n_updates        | 6610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.122    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 448      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 35392    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.271    |
# |    n_updates        | 8822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.128    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 443      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 44240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.419    |
# |    n_updates        | 11034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.181    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 444      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 53088    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.342    |
# |    n_updates        | 13246    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.219    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 445      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 61936    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.685    |
# |    n_updates        | 15458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.221    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 446      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 70784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.299    |
# |    n_updates        | 17670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.212    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 447      |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 79632    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 19882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.227    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 445      |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 88480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.269    |
# |    n_updates        | 22094    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.223    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 441      |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 97328    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.391    |
# |    n_updates        | 24306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.211    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 436      |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 106176   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.336    |
# |    n_updates        | 26518    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.199    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 436      |
# |    time_elapsed     | 263      |
# |    total_timesteps  | 115024   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.236    |
# |    n_updates        | 28730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.172    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 438      |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 123872   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.289    |
# |    n_updates        | 30942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.181    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 439      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 132720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.222    |
# |    n_updates        | 33154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.196    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 440      |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 141568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.294    |
# |    n_updates        | 35366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.219    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 441      |
# |    time_elapsed     | 340      |
# |    total_timesteps  | 150416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.571    |
# |    n_updates        | 37578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.215    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 442      |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 159264   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.311    |
# |    n_updates        | 39790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.235    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 442      |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 168112   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.185    |
# |    n_updates        | 42002    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.237    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 442      |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 176960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.28     |
# |    n_updates        | 44214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.231    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 443      |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 185808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.222    |
# |    n_updates        | 46426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.235    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 443      |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 194656   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 48638    |
# ----------------------------------
# Онлайн-дообучение — шаг 500
#
# === TEST METRICS ===
# final_balance: 9494.3232421875
# total_return: -0.05056767578125
# sharpe: -0.010092426091432571
# max_drawdown: -0.14412792026996613

# %%
data
# Out:
#       Unnamed: 0 Ticker        Open        High         Low       Close  \
# 0              0   TSLA  223.149994  224.149994  217.860001  218.259995
# 1              1   TSLA  218.289902  220.660004  218.000000  220.460297
# 2              2   TSLA  220.449997  221.237503  218.050003  218.380005
# 3              3   TSLA  218.410004  220.149994  217.639999  219.990005
# 4              4   TSLA  220.000000  221.460007  219.880005  220.949997
# ...          ...    ...         ...         ...         ...         ...
# 3488        3488   TSLA  434.225006  434.859985  426.290009  428.239990
# 3489        3489   TSLA  428.190002  429.279999  421.880005  428.743500
# 3490        3490   TSLA  428.755005  429.890015  424.440002  429.807587
# 3491        3491   TSLA  429.809906  433.890015  429.100006  432.405914
# 3492        3492   TSLA  432.440002  437.600006  431.010986  431.076599
#
#           Volume  Next_Close  Predicted_Close  price_t_plus_3  \
# 0     30510256.0  220.460297              NaN      219.990005
# 1     18283175.0  218.380005              NaN      220.949997
# 2     14518568.0  219.990005              NaN      221.940002
# 3     11122870.0  220.949997              NaN      222.100006
# 4     10069584.0  221.940002              NaN      213.980103
# ...          ...         ...              ...             ...
# 3488  10041263.0  428.743500       438.955597      432.405914
# 3489   9926006.0  429.807587       439.668732      431.076599
# 3490   6341342.0  432.405914       431.881012             NaN
# 3491   6470793.0  431.076599       432.385529             NaN
# 3492   8798520.0         NaN       434.308472             NaN
#
#       Predicted_Close_t_3
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 3488           433.686157
# 3489           431.694794
# 3490           425.598785
# 3491           426.487488
# 3492           429.454315
#
# [3493 rows x 11 columns]

# %%
test_size
# Out:
# 1440

# %%
print("\n=== ACTION STATS ===")
stats = env_test.get_action_stats()
print(f"Buys:  {stats['buys']}")
print(f"Sells: {stats['sells']}")
# Out:
# === ACTION STATS ===
# Buys:  64
# Sells: 312

# %%
class TradingEnvWithPrediction(gym.Env):
    metadata = {"render.modes": []}

    def __init__(self, prices, predicted_prices_1h=None, predicted_prices_3h=None,
                 window=24, initial_balance=10000, fee=0.001):
        super().__init__()
        self.prices = np.array(prices, dtype=np.float32).flatten()
        self.predicted_prices_1h = (np.array(predicted_prices_1h, dtype=np.float32).flatten()
                                    if predicted_prices_1h is not None else None)
        self.predicted_prices_3h = (np.array(predicted_prices_3h, dtype=np.float32).flatten()
                                    if predicted_prices_3h is not None else None)
        self.window = window
        self.initial_balance = initial_balance
        self.fee = fee

        self.balance = float(initial_balance)
        self.position = 0.0
        self.current_step = window
        self.equity_curve = []

        self.buy_count = 0
        self.sell_count = 0

        # 0=HOLD, 1=BUY, 2=SELL
        self.action_space = spaces.Discrete(3)

        # размер наблюдения: окно + баланс + позиция + 2 прогноза (если есть)
        obs_dim = window + 2
        if self.predicted_prices_1h is not None:
            obs_dim += 1
        if self.predicted_prices_3h is not None:
            obs_dim += 1

        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(obs_dim,),
            dtype=np.float32
        )

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.balance = float(self.initial_balance)
        self.position = 0.0
        self.current_step = self.window
        self.equity_curve = []
        self.buy_count = 0
        self.sell_count = 0

        obs = self._get_obs()
        info = {}
        return obs, info

    def _get_obs(self):
        window_data = self.prices[self.current_step - self.window:self.current_step]
        obs = [*window_data, self.balance, self.position]

        if self.predicted_prices_1h is not None:
            obs.append(self.predicted_prices_1h[self.current_step])
        if self.predicted_prices_3h is not None:
            obs.append(self.predicted_prices_3h[self.current_step])

        return np.array(obs, dtype=np.float32)

    def step(self, action):
        price = self.prices[self.current_step]

        if action == 1:  # BUY
            self.buy_count += 1
            if self.balance > 0:
                shares = self.balance / (price * (1 + self.fee))
                self.position += shares
                self.balance -= shares * price * (1 + self.fee)

        elif action == 2:  # SELL
            self.sell_count += 1
            if self.position > 0:
                self.balance += self.position * price * (1 - self.fee)
                self.position = 0.0

        equity = self.balance + self.position * price
        self.equity_curve.append(equity)

        reward = 0.0
        if len(self.equity_curve) > 1:
            reward = (equity - self.equity_curve[-2]) / (self.equity_curve[-2] + 1e-9)

        self.current_step += 1
        terminated = self.current_step >= len(self.prices) - 1
        truncated = False

        return self._get_obs(), reward, terminated, truncated, {}

    def get_metrics(self):
        curve = np.array(self.equity_curve, dtype=np.float32)

        final_balance = float(curve[-1])
        total_return = (final_balance - self.initial_balance) / self.initial_balance

        returns = np.diff(curve) / curve[:-1]
        sharpe = (
            np.mean(returns) / (np.std(returns) + 1e-9)
            if len(returns) > 1 else 0.0
        )

        running_max = np.maximum.accumulate(curve)
        max_dd = float(np.min((curve - running_max) / running_max))

        return {
            "final_balance": final_balance,
            "total_return": total_return,
            "sharpe": sharpe,
            "max_drawdown": max_dd
        }

    def get_action_stats(self):
        return {
            "buys": self.buy_count,
            "sells": self.sell_count
        }

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env

# --- Загружаем данные ---
data = pd.read_csv('data_.csv')  # предполагается, что есть колонки Close, Predicted_Close, Predicted_Close_3h
prices = data['Close'].to_numpy()
pred_prices_1h = data['Predicted_Close'].to_numpy()       # предсказание на 1 час вперед
pred_prices_3h = data['Predicted_Close_t_3'].to_numpy()    # предсказание на 3 часа вперед

# --- Train/Test Split ---
test_size = 30 * 24  # последний месяц
train_prices      = prices[500:-test_size]
train_pred_1h     = pred_prices_1h[500:-test_size]
train_pred_3h     = pred_prices_3h[500:-test_size]

test_prices       = prices[-test_size:]
test_pred_1h      = pred_prices_1h[-test_size:]
test_pred_3h      = pred_prices_3h[-test_size:]

# --- Окружения ---
window = 60
env_train = TradingEnvWithPrediction(
    prices=train_prices,
    predicted_prices_1h=train_pred_1h,
    predicted_prices_3h=train_pred_3h,
    window=window,
    fee=0.000
)
env_test = TradingEnvWithPrediction(
    prices=test_prices,
    predicted_prices_1h=test_pred_1h,
    predicted_prices_3h=test_pred_3h,
    window=window,
    fee=0.001
)

check_env(env_train, warn=True)
check_env(env_test, warn=True)

# --- Обучение модели ---
model = DQN(
    "MlpPolicy",
    env_train,
    verbose=1,
    learning_rate=1e-4,
    buffer_size=50_000,
    batch_size=64,
    gamma=0.99,
    train_freq=4,
    target_update_interval=1000,
)
model.learn(total_timesteps=200_000)

# --- Тест с онлайн-дообучением ---
obs, info = env_test.reset()
done = False
step = 0

while not done:
    action, _ = model.predict(obs, deterministic=False)
    next_obs, reward, done, truncated, info = env_test.step(action)

    # добавляем новый опыт в буфер
    model.replay_buffer.add(obs, next_obs, action, reward, done, infos=[info])

    # дообучаем на новых данных
    model.train(batch_size=64, gradient_steps=1)

    obs = next_obs
    step += 1

    if step % 500 == 0:
        print(f"Онлайн-дообучение — шаг {step}")

# --- Метрики ---
metrics = env_test.get_metrics()
print("\n=== TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.492    |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 639      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 8848     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 2186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.134    |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 581      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 17696    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.823    |
# |    n_updates        | 4398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.232    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 511      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 26544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.18     |
# |    n_updates        | 6610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.229    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 491      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 35392    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.6      |
# |    n_updates        | 8822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.255    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 479      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 44240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 11034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.252    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 471      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 53088    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.93     |
# |    n_updates        | 13246    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.262    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 465      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 61936    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.19     |
# |    n_updates        | 15458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.237    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 461      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 70784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.28     |
# |    n_updates        | 17670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.241    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 460      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 79632    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.919    |
# |    n_updates        | 19882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.254    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 458      |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 88480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59     |
# |    n_updates        | 22094    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.266    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 456      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 97328    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 24306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.273    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 455      |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 106176   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1        |
# |    n_updates        | 26518    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.277    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 455      |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 115024   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.24     |
# |    n_updates        | 28730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 453      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 123872   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31     |
# |    n_updates        | 30942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.315    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 452      |
# |    time_elapsed     | 293      |
# |    total_timesteps  | 132720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77     |
# |    n_updates        | 33154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.321    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 452      |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 141568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 35366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.311    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 451      |
# |    time_elapsed     | 333      |
# |    total_timesteps  | 150416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.916    |
# |    n_updates        | 37578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.305    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 449      |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 159264   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.24     |
# |    n_updates        | 39790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 451      |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 168112   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.976    |
# |    n_updates        | 42002    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.301    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 453      |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 176960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39     |
# |    n_updates        | 44214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.316    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 455      |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 185808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.24     |
# |    n_updates        | 46426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 0.313    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 456      |
# |    time_elapsed     | 426      |
# |    total_timesteps  | 194656   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.05     |
# |    n_updates        | 48638    |
# ----------------------------------
# Онлайн-дообучение — шаг 500
#
# === TEST METRICS ===
# final_balance: 9196.46484375
# total_return: -0.080353515625
# sharpe: -0.044256050139665604
# max_drawdown: -0.09938105195760727

# %%
class TradingEnvWithPrediction(gym.Env):
    metadata = {"render.modes": []}

    def __init__(self, prices, predictions=None,
                 window=24, initial_balance=10000, fee=0.001):
        """
        prices: np.array или список цен
        predictions: dict, где ключ — название прогноза, значение — массив предсказаний
                     пример: {"t1": predict_t1, "t3": predict_t3, "t8": predict_t8}
        """
        super().__init__()

        self.prices = np.array(prices, dtype=np.float32).flatten()
        self.predictions = {}

        if predictions is not None:
            for name, arr in predictions.items():
                self.predictions[name] = np.array(arr, dtype=np.float32).flatten()

        self.window = window
        self.initial_balance = initial_balance
        self.fee = fee

        self.balance = float(initial_balance)
        self.position = 0.0
        self.current_step = window
        self.equity_curve = []

        self.buy_count = 0
        self.sell_count = 0

        # --- Actions: 0 = HOLD, 1 = BUY, 2 = SELL ---
        self.action_space = spaces.Discrete(3)

        # --- Observation size ---
        obs_dim = window + 2 + len(self.predictions)
        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(obs_dim,),
            dtype=np.float32
        )
        

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.balance = float(self.initial_balance)
        self.position = 0.0
        self.current_step = self.window
        self.equity_curve = []
        self.buy_count = 0
        self.sell_count = 0

        obs = self._get_obs()
        info = {}
        return obs, info

    def _get_obs(self):
        window_data = self.prices[self.current_step - self.window:self.current_step]
        obs = [*window_data, self.balance, self.position]

        # Добавляем все прогнозы
        for arr in self.predictions.values():
            if self.current_step < len(arr):
                obs.append(arr[self.current_step])
            else:
                obs.append(np.nan)  # если вышли за пределы массива

        return np.array(obs, dtype=np.float32)

    def step(self, action):
        price = self.prices[self.current_step]
        prev_equity = self.balance + self.position * price
        
    
        # print(f"Step {self.current_step}: Price={price:.4f}, Balance={self.balance:.2f}, "
        #   f"Position={self.position:.4f}, Equity={prev_equity:.2f}")
    
        # --- Торговая логика с проверками ---
        trade_executed = False
        
        if action == 1:  # BUY
            if self.balance > 0:
                shares = self.balance / (price * (1 + self.fee))
                self.position += shares
                self.balance -= shares * price * (1 + self.fee)
                self.buy_count += 1
                trade_executed = True
            # else: можно добавить логирование попытки покупки без средств
        
        elif action == 2:  # SELL
            if self.position > 0:
                self.balance += self.position * price * (1 - self.fee)
                self.position = 0.0
                self.sell_count += 1
                trade_executed = True
            # else: можно добавить штраф за попытку продажи без позиции
        
        # --- Награда и метрики ---
        current_equity = self.balance + self.position * price
        # print(f"After action {action}: Equity={current_equity:.2f}, Change={current_equity-prev_equity:.2f}")
        self.equity_curve.append(current_equity)
        
        reward = 0.0
        if len(self.equity_curve) > 1:
            reward = (current_equity - prev_equity) / (prev_equity + 1e-9)
            
        price = self.prices[self.current_step]

        prev_price = self.prices[self.current_step - 1]

        reward = 0

        if self.position > 0:
            reward = (price - prev_price) / prev_price
        # Штраф за бесполезные действия
        # if not trade_executed and action != 0:  # действие не выполнено и это не HOLD
        #     reward -= 0.001  # небольшой штраф
        
        self.current_step += 1
        terminated = self.current_step >= len(self.prices) - 1
        
        return self._get_obs(), reward, terminated, False, {}

    def get_metrics(self):
        curve = np.array(self.equity_curve, dtype=np.float32)
        if len(curve) == 0:
            return {}

        final_balance = float(curve[-1])
        total_return = (final_balance - self.initial_balance) / self.initial_balance

        returns = np.diff(curve) / curve[:-1]
        sharpe = (
            np.mean(returns) / (np.std(returns) + 1e-9)
            if len(returns) > 1 else 0.0
        )

        running_max = np.maximum.accumulate(curve)
        max_dd = float(np.min((curve - running_max) / running_max))

        return {
            "final_balance": final_balance,
            "total_return": total_return,
            "sharpe": sharpe,
            "max_drawdown": max_dd
        }

    def get_action_stats(self):
        return {
            "buys": self.buy_count,
            "sells": self.sell_count
        }

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import SAC

# %%
# === 2. Загружаем данные ===
data = pd.read_csv("models/models/new_data.csv")  # должен содержать колонки: Close, predict_t1, predict_t3, predict_t8

prices = data["Close"].to_numpy()
pred_t1 = data["predict_t1"].to_numpy()
pred_t3 = data["predict_t3"].to_numpy()
pred_t8 = data["predict_t8"].to_numpy()

# === 3. Train/Test Split ===
test_size = 90 * 24  # например, 30 дней по 24 часа

train_prices = prices[500:-test_size]
train_preds = {
    "t1": pred_t1[500:-test_size],
    "t3": pred_t3[500:-test_size],
    "t8": pred_t8[500:-test_size],
}

test_prices = prices[-test_size:]
test_preds = {
    "t1": pred_t1[-test_size:],
    "t3": pred_t3[-test_size:],
    "t8": pred_t8[-test_size:],
}

# === 4. Создаём окружения ===
window = 60

env_train = TradingEnvWithPrediction(
    prices=train_prices,
    predictions=train_preds,
    window=window,
    fee=0.000
)

env_test = TradingEnvWithPrediction(
    prices=test_prices,
    predictions=test_preds,
    window=window,
    fee=0.001
)

# Проверим корректность среды
check_env(env_train, warn=True)
check_env(env_test, warn=True)

# === 5. Обучаем DQN ===
model = DQN(
    "MlpPolicy",
    env_train,
    verbose=1,
    learning_rate=1e-4,
    buffer_size=50_000,
    batch_size=64,
    gamma=0.99,
    train_freq=4,
    target_update_interval=1000,
)

# model = DQN.load("models/AAPL/dqn_trading_model", env=env_train)
print("🚀 Начинаем обучение модели...")
model.learn(total_timesteps=400_000)
print("✅ Обучение завершено.")

# === 6. Тест с онлайн-доподучением ===
obs, info = env_test.reset()
done = False
step = 0

while not done:
    action, _ = model.predict(obs, deterministic=False)
    next_obs, reward, done, truncated, info = env_test.step(action)

    # Добавляем опыт в буфер
    model.replay_buffer.add(obs, next_obs, action, reward, done, infos=[info])

    # Дообучаем на новых данных (онлайн)
    model.train(batch_size=64, gradient_steps=1)

    obs = next_obs
    step += 1

    if step % 500 == 0:
        print(f"Онлайн дообучение — шаг {step}")

print("✅ Тест завершён.")

# === 7. Метрики ===
metrics = env_test.get_metrics()
print("\n=== 📊 TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")

print("\n📈 Действия:", env_test.get_action_stats())


# obs, info = env_test.reset()
# done = False
# step = 0

# # Инициализация логгера
# from stable_baselines3.common.logger import configure
# model._logger = configure("logs/", ["stdout"])
# model._current_progress_remaining = 1.0

# while not done:
#     action, _ = model.predict(obs, deterministic=False)
#     next_obs, reward, done, truncated, info = env_test.step(action)

#     # Добавляем новый опыт в буфер
#     model.replay_buffer.add(obs, next_obs, action, reward, done, infos=[info])

#     # Дообучаем на новых данных
#     model.train(batch_size=64, gradient_steps=1)

#     obs = next_obs
#     step += 1

#     if step % 500 == 0:
#         print(f"Онлайн-дообучение — шаг {step}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 🚀 Начинаем обучение модели...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.369    |
# |    exploration_rate | 0.0713   |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 453      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 58652    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 23.8     |
# |    n_updates        | 14637    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.157    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 405      |
# |    time_elapsed     | 289      |
# |    total_timesteps  | 117304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 42.4     |
# |    n_updates        | 29300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.216    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 392      |
# |    time_elapsed     | 447      |
# |    total_timesteps  | 175956   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 20.3     |
# |    n_updates        | 43963    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.181    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 389      |
# |    time_elapsed     | 602      |
# |    total_timesteps  | 234608   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.4     |
# |    n_updates        | 58626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.253    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 386      |
# |    time_elapsed     | 758      |
# |    total_timesteps  | 293260   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.2      |
# |    n_updates        | 73289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.274    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 383      |
# |    time_elapsed     | 917      |
# |    total_timesteps  | 351912   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.81     |
# |    n_updates        | 87952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.307    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 383      |
# |    time_elapsed     | 1070     |
# |    total_timesteps  | 410564   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.48     |
# |    n_updates        | 102615   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.297    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 383      |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 469216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.53     |
# |    n_updates        | 117278   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.301    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 382      |
# |    time_elapsed     | 1378     |
# |    total_timesteps  | 527868   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 131941   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+04 |
# |    ep_rew_mean      | 0.351    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 383      |
# |    time_elapsed     | 1530     |
# |    total_timesteps  | 586520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11     |
# |    n_updates        | 146604   |
# ----------------------------------
# ✅ Обучение завершено.
# Онлайн дообучение — шаг 500
# ✅ Тест завершён.
#
# === 📊 TEST METRICS ===
# final_balance: 7556.5181
# total_return: -0.2443
# sharpe: -0.1231
# max_drawdown: -0.2490
#
# 📈 Действия: {'buys': 92, 'sells': 73}

# %%
import pandas as pd
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

# === 2. Загружаем данные ===
data = pd.read_csv("models/models/new_data.csv")  # должен содержать колонки: Close, predict_t1, predict_t3, predict_t8

prices = data["Close"].to_numpy()
pred_t1 = data["predict_t1"].to_numpy()
pred_t3 = data["predict_t3"].to_numpy()
pred_t8 = data["predict_t8"].to_numpy()

# === 3. Train/Test Split ===
test_size = 60 * 24  # например, 30 дней по 24 часа

train_prices = prices[500:-test_size]
train_preds = {
    "t1": pred_t1[500:-test_size],
    "t3": pred_t3[500:-test_size],
    "t8": pred_t8[500:-test_size],
}

test_prices = prices[-test_size:]
test_preds = {
    "t1": pred_t1[-test_size:],
    "t3": pred_t3[-test_size:],
    "t8": pred_t8[-test_size:],
}

# === 4. Создаём окружения ===
window = 60

env_train = TradingEnvSAC(
    prices=train_prices,
    predictions=train_preds,
    window=window,
    fee=0.000
)

env_test = TradingEnvSAC(
    prices=test_prices,
    predictions=test_preds,
    window=window,
    fee=0.001
)

# Проверим корректность среды
check_env(env_train, warn=True)
check_env(env_test, warn=True)

# === 5. Обучаем PPO ===
model = PPO(
    "MlpPolicy",
    env_train,
    verbose=1,
    learning_rate=3e-4,
    n_steps=2048,       # длина траектории
    batch_size=64,
    n_epochs=10,
    gamma=0.99,
    clip_range=0.2
)

print("🚀 Начинаем обучение модели PPO...")
model.learn(total_timesteps=400_000)
print("✅ Обучение завершено.")

# === 6. Тестирование ===
obs, info = env_test.reset()
done = False
step = 0

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env_test.step(action)
    step += 1

print("✅ Тест завершён.")

# === 7. Метрики ===
metrics = env_test.get_metrics()
print("\n=== 📊 TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 🚀 Начинаем обучение модели PPO...
# c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 310  |
# |    iterations      | 1    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0035340018 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -3.13        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0111      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 1            |
# |    value_loss           | 0.00333      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 235           |
# |    iterations           | 3             |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00062220346 |
# |    clip_fraction        | 0.00103       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00182       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | 8.66e-05      |
# |    std                  | 0.992         |
# |    value_loss           | 0.000228      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 226          |
# |    iterations           | 4            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0029893252 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.462       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00641      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00161     |
# |    std                  | 0.996        |
# |    value_loss           | 0.000436     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 222          |
# |    iterations           | 5            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0009806927 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00114      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000878    |
# |    std                  | 0.966        |
# |    value_loss           | 0.000275     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 221          |
# |    iterations           | 6            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0039057117 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0168       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00321     |
# |    std                  | 0.951        |
# |    value_loss           | 0.000234     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 7           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.002615841 |
# |    clip_fraction        | 0.0102      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00577    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00604    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000607   |
# |    std                  | 0.963       |
# |    value_loss           | 0.000332    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.363         |
# | time/                   |               |
# |    fps                  | 218           |
# |    iterations           | 8             |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00065392745 |
# |    clip_fraction        | 0.0109        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00271       |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000181     |
# |    std                  | 0.958         |
# |    value_loss           | 0.00015       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.363       |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 9           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004329332 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00174    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00182    |
# |    std                  | 0.951       |
# |    value_loss           | 9.74e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.363        |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 10           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0014447893 |
# |    clip_fraction        | 0.00503      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0113       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000487    |
# |    std                  | 0.966        |
# |    value_loss           | 0.00023      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.54e+04   |
# |    ep_rew_mean          | 0.363      |
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 11         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00218687 |
# |    clip_fraction        | 0.0169     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00441    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.000743  |
# |    std                  | 0.954      |
# |    value_loss           | 0.000216   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.363       |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 12          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.003860212 |
# |    clip_fraction        | 0.00645     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0019     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00605     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.000443   |
# |    std                  | 0.953       |
# |    value_loss           | 0.000252    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.363        |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 13           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0013522187 |
# |    clip_fraction        | 0.00708      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00411      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000312    |
# |    std                  | 0.939        |
# |    value_loss           | 0.000189     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.363        |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 14           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0015980504 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00145     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0031       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00126     |
# |    std                  | 0.937        |
# |    value_loss           | 0.000243     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.363        |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 15           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0045682117 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00235     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00133     |
# |    std                  | 0.919        |
# |    value_loss           | 0.00011      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.145        |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 16           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0018135204 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0116       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000759    |
# |    std                  | 0.918        |
# |    value_loss           | 5.44e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.145        |
# | time/                   |              |
# |    fps                  | 203          |
# |    iterations           | 17           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0011902053 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000953     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000549    |
# |    std                  | 0.919        |
# |    value_loss           | 0.000128     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 18          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 1.52055e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000174    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.000308    |
# |    std                  | 0.923       |
# |    value_loss           | 0.000131    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.54e+04   |
# |    ep_rew_mean          | 0.145      |
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 19         |
# |    time_elapsed         | 189        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00768314 |
# |    clip_fraction        | 0.0421     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.00789    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00619    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00278   |
# |    std                  | 0.932      |
# |    value_loss           | 0.000178   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.145        |
# | time/                   |              |
# |    fps                  | 206          |
# |    iterations           | 20           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0031710379 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00618     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000975    |
# |    std                  | 0.933        |
# |    value_loss           | 0.000137     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 21          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005695571 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00774    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00253    |
# |    std                  | 0.925       |
# |    value_loss           | 0.000146    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.145        |
# | time/                   |              |
# |    fps                  | 207          |
# |    iterations           | 22           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0002978661 |
# |    clip_fraction        | 0.00366      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.0154      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000489    |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000124    |
# |    std                  | 0.934        |
# |    value_loss           | 8.19e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.117        |
# | time/                   |              |
# |    fps                  | 208          |
# |    iterations           | 23           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0018562025 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00708      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000973    |
# |    std                  | 0.951        |
# |    value_loss           | 7.88e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.117       |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 24          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004079976 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00966    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00284    |
# |    std                  | 0.95        |
# |    value_loss           | 8.48e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.54e+04   |
# |    ep_rew_mean          | 0.117      |
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 25         |
# |    time_elapsed         | 244        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00557416 |
# |    clip_fraction        | 0.0422     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0226    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00265   |
# |    std                  | 0.945      |
# |    value_loss           | 0.000222   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.117        |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 26           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0061226496 |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0103      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00269     |
# |    std                  | 0.938        |
# |    value_loss           | 9.16e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.117         |
# | time/                   |               |
# |    fps                  | 209           |
# |    iterations           | 27            |
# |    time_elapsed         | 263           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00046347687 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 3.25e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00105       |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -2.52e-05     |
# |    std                  | 0.953         |
# |    value_loss           | 0.000102      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.117       |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 28          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.002322889 |
# |    clip_fraction        | 0.0246      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000715    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00173    |
# |    std                  | 0.941       |
# |    value_loss           | 6.51e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.117        |
# | time/                   |              |
# |    fps                  | 210          |
# |    iterations           | 29           |
# |    time_elapsed         | 282          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0017612684 |
# |    clip_fraction        | 0.00884      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000172     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0185      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000254    |
# |    std                  | 0.946        |
# |    value_loss           | 8.71e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.117        |
# | time/                   |              |
# |    fps                  | 210          |
# |    iterations           | 30           |
# |    time_elapsed         | 291          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0013693217 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00246      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.923        |
# |    value_loss           | 3.4e-05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | -0.0067      |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 31           |
# |    time_elapsed         | 300          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0026195538 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.015        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.917        |
# |    value_loss           | 2.35e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | -0.0067      |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 32           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0038271714 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0144       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.000118     |
# |    std                  | 0.92         |
# |    value_loss           | 0.000129     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | -0.0067     |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 33          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005781895 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00377    |
# |    std                  | 0.906       |
# |    value_loss           | 0.000364    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | -0.0067      |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 34           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0009870993 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.000202     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00124      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000368    |
# |    std                  | 0.899        |
# |    value_loss           | 0.000226     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | -0.0067      |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 35           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0024043296 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00121      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000718    |
# |    std                  | 0.879        |
# |    value_loss           | 0.000229     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | -0.0067      |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 36           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0010916118 |
# |    clip_fraction        | 0.00166      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00819      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.000152     |
# |    std                  | 0.888        |
# |    value_loss           | 0.000306     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | -0.0067       |
# | time/                   |               |
# |    fps                  | 212           |
# |    iterations           | 37            |
# |    time_elapsed         | 356           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00056275056 |
# |    clip_fraction        | 0.00254       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | -0.00122      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00702      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000115     |
# |    std                  | 0.87          |
# |    value_loss           | 0.000459      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.107        |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 38           |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0030393158 |
# |    clip_fraction        | 0.0061       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0128       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000829    |
# |    std                  | 0.853        |
# |    value_loss           | 0.000142     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.107        |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 39           |
# |    time_elapsed         | 375          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0051317727 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00253      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000718    |
# |    std                  | 0.844        |
# |    value_loss           | 0.000129     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.107         |
# | time/                   |               |
# |    fps                  | 212           |
# |    iterations           | 40            |
# |    time_elapsed         | 384           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00027777549 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.25         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00606      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | 0.000218      |
# |    std                  | 0.851         |
# |    value_loss           | 0.000314      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.107        |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 41           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0032756445 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00012      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00153     |
# |    std                  | 0.846        |
# |    value_loss           | 0.000328     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.107        |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 42           |
# |    time_elapsed         | 404          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0005890388 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -0.00163     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00275     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000334     |
# |    std                  | 0.849        |
# |    value_loss           | 0.000397     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.107       |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 43          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005389707 |
# |    clip_fraction        | 0.0165      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.009       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.000526   |
# |    std                  | 0.842       |
# |    value_loss           | 0.000349    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.107       |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 44          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.002474092 |
# |    clip_fraction        | 0.01        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -0.000186   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00912     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.000605   |
# |    std                  | 0.836       |
# |    value_loss           | 0.00086     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.107         |
# | time/                   |               |
# |    fps                  | 213           |
# |    iterations           | 45            |
# |    time_elapsed         | 431           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00045368186 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.23         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.62e-05      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | 0.000234      |
# |    std                  | 0.827         |
# |    value_loss           | 0.000333      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.272        |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 46           |
# |    time_elapsed         | 440          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0042275926 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00722      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00149     |
# |    std                  | 0.822        |
# |    value_loss           | 0.000282     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.272       |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 47          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004148001 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00211    |
# |    std                  | 0.816       |
# |    value_loss           | 0.000187    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.272        |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 48           |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0051977453 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00741     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00114     |
# |    std                  | 0.807        |
# |    value_loss           | 0.000314     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 0.272         |
# | time/                   |               |
# |    fps                  | 213           |
# |    iterations           | 49            |
# |    time_elapsed         | 469           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00022507153 |
# |    clip_fraction        | 0.0112        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.2          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00168       |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000562     |
# |    std                  | 0.808         |
# |    value_loss           | 0.000243      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.272        |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 50           |
# |    time_elapsed         | 478          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0013462356 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -0.000636    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00303     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00175     |
# |    std                  | 0.794        |
# |    value_loss           | 0.000147     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 0.272       |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 51          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.002981801 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0098      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00101    |
# |    std                  | 0.79        |
# |    value_loss           | 0.000507    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 0.272        |
# | time/                   |              |
# |    fps                  | 214          |
# |    iterations           | 52           |
# |    time_elapsed         | 497          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0029441495 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -8.34e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00511      |
# ...
# | time/                   |               |
# |    fps                  | 211           |
# |    iterations           | 180           |
# |    time_elapsed         | 1745          |
# |    total_timesteps      | 368640        |
# | train/                  |               |
# |    approx_kl            | 0.00081018766 |
# |    clip_fraction        | 0.00962       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.679        |
# |    explained_variance   | 0.000126      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00534       |
# |    n_updates            | 1790          |
# |    policy_gradient_loss | 0.000243      |
# |    std                  | 0.477         |
# |    value_loss           | 0.000851      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 1.06        |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 181         |
# |    time_elapsed         | 1754        |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.004198569 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00512    |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00207    |
# |    std                  | 0.478       |
# |    value_loss           | 0.000494    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 1.06         |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 182          |
# |    time_elapsed         | 1764         |
# |    total_timesteps      | 372736       |
# | train/                  |              |
# |    approx_kl            | 0.0013568334 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00309      |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.488        |
# |    value_loss           | 0.000429     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 1.06          |
# | time/                   |               |
# |    fps                  | 211           |
# |    iterations           | 183           |
# |    time_elapsed         | 1774          |
# |    total_timesteps      | 374784        |
# | train/                  |               |
# |    approx_kl            | 0.00086800335 |
# |    clip_fraction        | 0.0147        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.696        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00618      |
# |    n_updates            | 1820          |
# |    policy_gradient_loss | -0.000118     |
# |    std                  | 0.482         |
# |    value_loss           | 0.000284      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 1.06         |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 184          |
# |    time_elapsed         | 1784         |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0008282935 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.696       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00433     |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.000307    |
# |    std                  | 0.488        |
# |    value_loss           | 0.000392     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 1.06        |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 185         |
# |    time_elapsed         | 1794        |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.001294446 |
# |    clip_fraction        | 0.0128      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.699      |
# |    explained_variance   | 0.000912    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00256     |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.000251   |
# |    std                  | 0.485       |
# |    value_loss           | 0.000327    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 1.06         |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 186          |
# |    time_elapsed         | 1803         |
# |    total_timesteps      | 380928       |
# | train/                  |              |
# |    approx_kl            | 0.0040885303 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000214     |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.000333    |
# |    std                  | 0.484        |
# |    value_loss           | 0.000239     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 1.06         |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 187          |
# |    time_elapsed         | 1813         |
# |    total_timesteps      | 382976       |
# | train/                  |              |
# |    approx_kl            | 0.0004428383 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00405     |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | 0.000177     |
# |    std                  | 0.482        |
# |    value_loss           | 0.000419     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 1.06         |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 188          |
# |    time_elapsed         | 1823         |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0004584405 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | 0.000212     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00528      |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.000408    |
# |    std                  | 0.484        |
# |    value_loss           | 0.000499     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 189         |
# |    time_elapsed         | 1833        |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.002402281 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00824    |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00111    |
# |    std                  | 0.477       |
# |    value_loss           | 0.000223    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 1.05         |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 190          |
# |    time_elapsed         | 1843         |
# |    total_timesteps      | 389120       |
# | train/                  |              |
# |    approx_kl            | 0.0045708176 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.676       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0323      |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.000352    |
# |    std                  | 0.474        |
# |    value_loss           | 0.000194     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.54e+04     |
# |    ep_rew_mean          | 1.05         |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 191          |
# |    time_elapsed         | 1852         |
# |    total_timesteps      | 391168       |
# | train/                  |              |
# |    approx_kl            | 0.0038470651 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0275       |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | 6.71e-05     |
# |    std                  | 0.475        |
# |    value_loss           | 0.000469     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 192         |
# |    time_elapsed         | 1862        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.001198601 |
# |    clip_fraction        | 0.0019      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00291     |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 6.52e-05    |
# |    std                  | 0.468       |
# |    value_loss           | 0.000284    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 193         |
# |    time_elapsed         | 1872        |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.002092931 |
# |    clip_fraction        | 0.0145      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 8.19e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00071     |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.000308   |
# |    std                  | 0.472       |
# |    value_loss           | 0.000404    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 1.05          |
# | time/                   |               |
# |    fps                  | 211           |
# |    iterations           | 194           |
# |    time_elapsed         | 1882          |
# |    total_timesteps      | 397312        |
# | train/                  |               |
# |    approx_kl            | 0.00053288916 |
# |    clip_fraction        | 0.00479       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.661        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00824       |
# |    n_updates            | 1930          |
# |    policy_gradient_loss | 0.000289      |
# |    std                  | 0.465         |
# |    value_loss           | 0.000704      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.54e+04      |
# |    ep_rew_mean          | 1.05          |
# | time/                   |               |
# |    fps                  | 211           |
# |    iterations           | 195           |
# |    time_elapsed         | 1892          |
# |    total_timesteps      | 399360        |
# | train/                  |               |
# |    approx_kl            | 0.00014631747 |
# |    clip_fraction        | 0.0159        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.651        |
# |    explained_variance   | 2.34e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0012        |
# |    n_updates            | 1940          |
# |    policy_gradient_loss | -0.00045      |
# |    std                  | 0.462         |
# |    value_loss           | 0.000869      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+04    |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 196         |
# |    time_elapsed         | 1902        |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.007197195 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0278     |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.00373    |
# |    std                  | 0.451       |
# |    value_loss           | 0.00057     |
# -----------------------------------------
# ✅ Обучение завершено.
# ✅ Тест завершён.
#
# === 📊 TEST METRICS ===
# final_equity: 0.7158
# final_position: 1.0000

# %%
# === 7. Метрики ===
metrics = env_test.get_metrics()
print("\n=== 📊 TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")

# print("\n📈 Действия:", env_test.get_action_stats())
# Out:
# === 📊 TEST METRICS ===
# final_equity: 0.7158
# final_position: 1.0000

# %%
import gymnasium as gym
import numpy as np


class TradingEnvSAC(gym.Env):
    """
    Continuous-action trading environment for SAC.
    Action = [-1 ... +1]  → position size (fraction of equity).
    """

    metadata = {"render.modes": ["human"]}

    def __init__(self, prices, predictions, window=60, fee=0.001):
        super().__init__()

        # ====== SANITIZE INPUT DATA ======
        prices = np.nan_to_num(prices, nan=1.0, posinf=1.0, neginf=1.0)
        self.prices = prices.astype(np.float32)

        self.pred_t1 = np.nan_to_num(predictions["t1"], nan=0.0).astype(np.float32)
        self.pred_t3 = np.nan_to_num(predictions["t3"], nan=0.0).astype(np.float32)
        self.pred_t8 = np.nan_to_num(predictions["t8"], nan=0.0).astype(np.float32)

        self.window = window
        self.fee = fee

        # === Action space: one continuous [-1..1]
        self.action_space = gym.spaces.Box(
            low=np.array([-1.0], dtype=np.float32),
            high=np.array([1.0], dtype=np.float32),
            shape=(1,),
            dtype=np.float32
        )

        # === Observation size ===
        obs_size = window * 4 + 2
        self.observation_space = gym.spaces.Box(
            low=-np.inf, high=np.inf,
            shape=(obs_size,), dtype=np.float32
        )

        self.reset()

    # =====================================================================
    #                           RESET
    # =====================================================================
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.step_index = self.window
        self.position = 0.0
        self.equity = 1.0
        self.prev_equity = 1.0

        obs = self._get_obs()
        return obs, {}

    # =====================================================================
    #                           STEP
    # =====================================================================
    def step(self, action):
        # ========= VALIDATE ACTION =========
        try:
            action = float(action[0])
        except:
            raise ValueError(f"Action has wrong format: {action}")

        if np.isnan(action):
            raise ValueError("ACTION IS NaN!")

        action = np.clip(action, -1, 1)
        new_position = action

        # ========= PRICE =========
        price = self.prices[self.step_index]
        prev_price = self.prices[self.step_index - 1]

        if prev_price == 0:
            prev_price = 1e-6

        # ========= POSITION CHANGE COST =========
        pos_change = abs(new_position - self.position)
        fee_cost = pos_change * self.fee
        self.equity *= (1 - min(fee_cost, 0.99))

        # ========= PRICE CHANGE =========
        price_change = (price - prev_price) / prev_price
        price_change = float(np.nan_to_num(price_change, nan=0.0))

        # ========= EQUITY UPDATE =========
        ret = 1 + self.position * price_change
        ret = float(np.nan_to_num(ret, nan=1.0))

        # prevents collapse
        ret = max(ret, 1e-6)

        self.equity *= ret
        self.equity = float(np.nan_to_num(self.equity, nan=self.prev_equity))

        # ========= REWARD =========
        reward = self.equity - self.prev_equity
        reward = float(np.nan_to_num(reward, nan=0.0))
        if np.isnan(reward) or np.isinf(reward):
            raise ValueError("Reward became NaN/Inf")

        self.prev_equity = self.equity
        self.position = new_position

        # ========= NEXT STEP =========
        self.step_index += 1
        terminated = self.step_index >= len(self.prices) - 1

        obs = self._get_obs()

        # ========= VALIDATE OBS =========
        if np.any(np.isnan(obs)):
            print("\n\n===== NaN FOUND IN OBSERVATION =====")
            print("Step:", self.step_index)
            print("prices slice:", self.prices[self.step_index - self.window:self.step_index])
            print("pred_t1 slice:", self.pred_t1[self.step_index - self.window:self.step_index])
            print("equity:", self.equity)
            print("position:", self.position)
            raise ValueError("OBS contains NaN!")

        return obs, reward, terminated, False, {}

    # =====================================================================
    #                           OBSERVATION
    # =====================================================================
    def _get_obs(self):
        i = self.step_index

        prices = self.prices[i - self.window:i]
        t1 = self.pred_t1[i - self.window:i]
        t3 = self.pred_t3[i - self.window:i]
        t8 = self.pred_t8[i - self.window:i]

        obs = np.concatenate([
            prices,
            t1,
            t3,
            t8,
            np.array([self.position], dtype=np.float32),
            np.array([self.equity], dtype=np.float32),
        ])

        # ABSOLUTE PROTECTION
        obs = np.nan_to_num(obs, nan=0.0, posinf=1e6, neginf=-1e6)

        return obs.astype(np.float32)

    # =====================================================================
    #                           METRICS
    # =====================================================================
    def get_metrics(self):
        return {
            "final_equity": float(self.equity),
            "final_position": float(self.position),
        }

# %%
# === 2. Загружаем данные ===
data = pd.read_csv("models/models/new_data.csv")

prices = data["Close"].to_numpy()
pred_t1 = data["predict_t1"].to_numpy()
pred_t3 = data["predict_t3"].to_numpy()
pred_t8 = data["predict_t8"].to_numpy()

# === 3. Train/Test Split ===
test_size = 60 * 24

train_prices = prices[500:-test_size]
train_preds = {
    "t1": pred_t1[500:-test_size],
    "t3": pred_t3[500:-test_size],
    "t8": pred_t8[500:-test_size],
}

test_prices = prices[-test_size:]
test_preds = {
    "t1": pred_t1[-test_size:],
    "t3": pred_t3[-test_size:],
    "t8": pred_t8[-test_size:],
}

# === 4. Создаём окружения ===
window = 60

env_train = TradingEnvSAC(
    prices=train_prices,
    predictions=train_preds,
    window=window,
    fee=0.000
)

env_test = TradingEnvSAC(
    prices=test_prices,
    predictions=test_preds,
    window=window,
    fee=0.001
)

check_env(env_train)
check_env(env_test)

# === 5. Обучаем SAC ===
model = SAC(
    "MlpPolicy",
    env_train,
    verbose=1,
    learning_rate=3e-4,
    gamma=0.99,
    buffer_size=200_000,
    batch_size=256,
    train_freq=1,
    gradient_steps=1,
    tau=0.02,
    ent_coef="auto",   
)

print("🚀 Начинаем обучение SAC...")
model.learn(total_timesteps=400_000)
print("✅ Обучение завершено.")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 🚀 Начинаем обучение SAC...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+04 |
# |    ep_rew_mean     | -0.761   |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 34       |
# |    time_elapsed    | 1768     |
# |    total_timesteps | 61772    |
# | train/             |          |
# |    actor_loss      | 1.39e+11 |
# |    critic_loss     | 8.68e+17 |
# |    ent_coef        | 1.09e+08 |
# |    ent_coef_loss   | -590     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 61671    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.54e+04  |
# |    ep_rew_mean     | -0.76     |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 35        |
# |    time_elapsed    | 3528      |
# |    total_timesteps | 123544    |
# | train/             |           |
# |    actor_loss      | 4e+17     |
# |    critic_loss     | 1.56e+35  |
# |    ent_coef        | 1.21e+16  |
# |    ent_coef_loss   | -1.18e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 123443    |
# ----------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 62
#      47 model = SAC(
#      48     "MlpPolicy",
#      49     env_train,
#    (...)     58     ent_coef="auto",
#      59 )
#      61 print("🚀 Начинаем обучение SAC...")
# ---> 62 model.learn(total_timesteps=400_000)
#      63 print("✅ Обучение завершено.")
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\sac\sac.py:313, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     304 def learn(
#     305     self: SelfSAC,
#     306     total_timesteps: int,
#    (...)    311     progress_bar: bool = False,
#     312 ) -> SelfSAC:
# --> 313     return super().learn(
#     314         total_timesteps=total_timesteps,
#     315         callback=callback,
#     316         log_interval=log_interval,
#     317         tb_log_name=tb_log_name,
#     318         reset_num_timesteps=reset_num_timesteps,
#     319         progress_bar=progress_bar,
#     320     )
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:335, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     332 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     334 while self.num_timesteps < total_timesteps:
# --> 335     rollout = self.collect_rollouts(
#     336         self.env,
#     337         train_freq=self.train_freq,
#     338         action_noise=self.action_noise,
#     339         callback=callback,
#     340         learning_starts=self.learning_starts,
#     341         replay_buffer=self.replay_buffer,
#     342         log_interval=log_interval,
#     343     )
#     345     if not rollout.continue_training:
#     346         break
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:564, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     561     self.actor.reset_noise(env.num_envs)  # type: ignore[operator]
#     563 # Select action randomly or according to policy
# --> 564 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     566 # Rescale and perform action
#     567 new_obs, rewards, dones, infos = env.step(actions)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:397, in OffPolicyAlgorithm._sample_action(self, learning_starts, action_noise, n_envs)
#     392 else:
#     393     # Note: when using continuous actions,
#     394     # we assume that the policy uses tanh to scale the action
#     395     # We use non-deterministic action in the case of SAC, for TD3, it does not matter
#     396     assert self._last_obs is not None, "self._last_obs was not set"
# --> 397     unscaled_action, _ = self.predict(self._last_obs, deterministic=False)
#     399 # Rescale the action from [low, high] to [-1, 1]
#     400 if isinstance(self.action_space, spaces.Box):
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\base_class.py:557, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     537 def predict(
#     538     self,
#     539     observation: Union[np.ndarray, dict[str, np.ndarray]],
#    (...)    542     deterministic: bool = False,
#     543 ) -> tuple[np.ndarray, Optional[tuple[np.ndarray, ...]]]:
#     544     """
#     545     Get the policy action from an observation (and optional hidden state).
#     546     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)    555         (used in recurrent policies)
#     556     """
# --> 557     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc, assignment]
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\sac\policies.py:353, in SACPolicy._predict(self, observation, deterministic)
#     352 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
# --> 353     return self.actor(observation, deterministic)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\sac\policies.py:170, in Actor.forward(self, obs, deterministic)
#     168 mean_actions, log_std, kwargs = self.get_action_dist_params(obs)
#     169 # Note: the action is squashed
# --> 170 return self.action_dist.actions_from_params(mean_actions, log_std, deterministic=deterministic, **kwargs)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\distributions.py:190, in DiagGaussianDistribution.actions_from_params(self, mean_actions, log_std, deterministic)
#     188 def actions_from_params(self, mean_actions: th.Tensor, log_std: th.Tensor, deterministic: bool = False) -> th.Tensor:
#     189     # Update the proba distribution
# --> 190     self.proba_distribution(mean_actions, log_std)
#     191     return self.get_actions(deterministic=deterministic)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\distributions.py:224, in SquashedDiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     221 def proba_distribution(
#     222     self: SelfSquashedDiagGaussianDistribution, mean_actions: th.Tensor, log_std: th.Tensor
#     223 ) -> SelfSquashedDiagGaussianDistribution:
# --> 224     super().proba_distribution(mean_actions, log_std)
#     225     return self
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)    161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\distributions\normal.py:66, in Normal.__init__(self, loc, scale, validate_args)
#      64 else:
#      65     batch_shape = self.loc.size()
# ---> 66 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\distributions\distribution.py:77, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      75         valid = constraint.check(value)
#      76         if not torch._is_all_true(valid):
# ---> 77             raise ValueError(
#      78                 f"Expected parameter {param} "
#      79                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      80                 f"of distribution {repr(self)} "
#      81                 f"to satisfy the constraint {repr(constraint)}, "
#      82                 f"but found invalid values:\n{value}"
#      83             )
#      84 super().__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (1, 1)) of distribution Normal(loc: tensor([[nan]], device='cuda:0'), scale: tensor([[nan]], device='cuda:0')) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan]], device='cuda:0')

# %%
# model.save("models/sac_trading_model")

# === 6. Тестирование (без онлайн-дообучения) ===
obs, info = env_test.reset()
done = False

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env_test.step(action)

print("✅ Тестирование завершено.")

# === 7. Метрики ===
metrics = env_test.get_metrics()
print("\n=== 📊 TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")

print("\n📈 Действия:", env_test.get_action_stats())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 8
#       5 done = False
#       7 while not done:
# ----> 8     action, _ = model.predict(obs, deterministic=True)
#       9     obs, reward, done, truncated, info = env_test.step(action)
#      11 print("✅ Тестирование завершено.")
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\base_class.py:557, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     537 def predict(
#     538     self,
#     539     observation: Union[np.ndarray, dict[str, np.ndarray]],
#    (...)    542     deterministic: bool = False,
#     543 ) -> tuple[np.ndarray, Optional[tuple[np.ndarray, ...]]]:
#     544     """
#     545     Get the policy action from an observation (and optional hidden state).
#     546     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)    555         (used in recurrent policies)
#     556     """
# --> 557     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc, assignment]
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\sac\policies.py:353, in SACPolicy._predict(self, observation, deterministic)
#     352 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
# --> 353     return self.actor(observation, deterministic)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\sac\policies.py:170, in Actor.forward(self, obs, deterministic)
#     168 mean_actions, log_std, kwargs = self.get_action_dist_params(obs)
#     169 # Note: the action is squashed
# --> 170 return self.action_dist.actions_from_params(mean_actions, log_std, deterministic=deterministic, **kwargs)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\distributions.py:190, in DiagGaussianDistribution.actions_from_params(self, mean_actions, log_std, deterministic)
#     188 def actions_from_params(self, mean_actions: th.Tensor, log_std: th.Tensor, deterministic: bool = False) -> th.Tensor:
#     189     # Update the proba distribution
# --> 190     self.proba_distribution(mean_actions, log_std)
#     191     return self.get_actions(deterministic=deterministic)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\distributions.py:224, in SquashedDiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     221 def proba_distribution(
#     222     self: SelfSquashedDiagGaussianDistribution, mean_actions: th.Tensor, log_std: th.Tensor
#     223 ) -> SelfSquashedDiagGaussianDistribution:
# --> 224     super().proba_distribution(mean_actions, log_std)
#     225     return self
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)    161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\distributions\normal.py:66, in Normal.__init__(self, loc, scale, validate_args)
#      64 else:
#      65     batch_shape = self.loc.size()
# ---> 66 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\distributions\distribution.py:77, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      75         valid = constraint.check(value)
#      76         if not torch._is_all_true(valid):
# ---> 77             raise ValueError(
#      78                 f"Expected parameter {param} "
#      79                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      80                 f"of distribution {repr(self)} "
#      81                 f"to satisfy the constraint {repr(constraint)}, "
#      82                 f"but found invalid values:\n{value}"
#      83             )
#      84 super().__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (1, 1)) of distribution Normal(loc: tensor([[nan]], device='cuda:0'), scale: tensor([[nan]], device='cuda:0')) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan]], device='cuda:0')

# %%
metrics
# Out:
# {'final_balance': 9176.0419921875,
#  'total_return': -0.08239580078125,
#  'sharpe': np.float32(-0.17734689),
#  'max_drawdown': -0.08794286847114563}

# %%
model.save("models/dqn_trading_model")

# %%
# === 6. Тестирование (без онлайн-дообучения) ===
obs, info = env_test.reset()
done = False

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env_test.step(action)

print("✅ Тестирование завершено.")

# === 7. Метрики ===
metrics = env_test.get_metrics()
print("\n=== 📊 TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")

print("\n📈 Действия:", env_test.get_action_stats())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 6
#       3 done = False
#       5 while not done:
# ----> 6     action, _ = model.predict(obs, deterministic=True)
#       7     obs, reward, done, truncated, info = env_test.step(action)
#       9 print("✅ Тестирование завершено.")
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\base_class.py:557, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     537 def predict(
#     538     self,
#     539     observation: Union[np.ndarray, dict[str, np.ndarray]],
#    (...)    542     deterministic: bool = False,
#     543 ) -> tuple[np.ndarray, Optional[tuple[np.ndarray, ...]]]:
#     544     """
#     545     Get the policy action from an observation (and optional hidden state).
#     546     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)    555         (used in recurrent policies)
#     556     """
# --> 557     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc, assignment]
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\sac\policies.py:353, in SACPolicy._predict(self, observation, deterministic)
#     352 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
# --> 353     return self.actor(observation, deterministic)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\sac\policies.py:170, in Actor.forward(self, obs, deterministic)
#     168 mean_actions, log_std, kwargs = self.get_action_dist_params(obs)
#     169 # Note: the action is squashed
# --> 170 return self.action_dist.actions_from_params(mean_actions, log_std, deterministic=deterministic, **kwargs)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\distributions.py:190, in DiagGaussianDistribution.actions_from_params(self, mean_actions, log_std, deterministic)
#     188 def actions_from_params(self, mean_actions: th.Tensor, log_std: th.Tensor, deterministic: bool = False) -> th.Tensor:
#     189     # Update the proba distribution
# --> 190     self.proba_distribution(mean_actions, log_std)
#     191     return self.get_actions(deterministic=deterministic)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\distributions.py:224, in SquashedDiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     221 def proba_distribution(
#     222     self: SelfSquashedDiagGaussianDistribution, mean_actions: th.Tensor, log_std: th.Tensor
#     223 ) -> SelfSquashedDiagGaussianDistribution:
# --> 224     super().proba_distribution(mean_actions, log_std)
#     225     return self
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)    161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\distributions\normal.py:66, in Normal.__init__(self, loc, scale, validate_args)
#      64 else:
#      65     batch_shape = self.loc.size()
# ---> 66 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\distributions\distribution.py:77, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      75         valid = constraint.check(value)
#      76         if not torch._is_all_true(valid):
# ---> 77             raise ValueError(
#      78                 f"Expected parameter {param} "
#      79                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      80                 f"of distribution {repr(self)} "
#      81                 f"to satisfy the constraint {repr(constraint)}, "
#      82                 f"but found invalid values:\n{value}"
#      83             )
#      84 super().__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (1, 1)) of distribution Normal(loc: tensor([[nan]], device='cuda:0'), scale: tensor([[nan]], device='cuda:0')) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan]], device='cuda:0')

# %%
data["Close"].isna().sum()

data["predict_t1"].isna().sum()
data["predict_t3"].isna().sum()
data["predict_t8"].isna().sum()
# Out:
# np.int64(61)

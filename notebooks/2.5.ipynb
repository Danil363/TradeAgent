# %%
import pandas as pd
import numpy as np
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
import gymnasium as gym
from gymnasium import spaces

# %%
import numpy as np
import gymnasium as gym
from gymnasium import spaces

class MultiAssetTradingEnv(gym.Env):
    metadata = {"render.modes": []}

    def __init__(self, prices_dict, predictions_dict=None,
                 window=24, initial_balance=10000, fee=0.001):
        """
        prices_dict: {'MSFT': np.array, 'AAPL': np.array, ...}
        predictions_dict: {'MSFT': {'t1': ..., 't3': ...}, 'AAPL': {...}, ...}
        """
        super().__init__()

        self.assets = list(prices_dict.keys())
        self.num_assets = len(self.assets)

        self.prices_dict = {k: np.array(v, dtype=np.float32).flatten() for k, v in prices_dict.items()}
        self.predictions_dict = {}
        if predictions_dict is not None:
            for asset, preds in predictions_dict.items():
                self.predictions_dict[asset] = {k: np.array(v, dtype=np.float32).flatten() for k,v in preds.items()}

        self.window = window
        self.initial_balance = initial_balance
        self.fee = fee

        self.balance = {asset: float(initial_balance) for asset in self.assets}
        self.positions = {asset: 0.0 for asset in self.assets}
        self.current_step = window
        self.equity_curve = []

        # MultiDiscrete: для каждого актива 3 действия (0=HOLD,1=BUY,2=SELL)
        self.action_space = spaces.MultiDiscrete([3]*self.num_assets)

        # Размер наблюдения: для каждого актива window+2+кол-во прогнозов
        n_preds = len(next(iter(self.predictions_dict[self.assets[0]]))) if self.predictions_dict else 0
        obs_dim = self.num_assets * (window + 2 + n_preds)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(195,), dtype=np.float32)

        self.done = False
        self.max_steps = min(len(p) for p in self.prices_dict.values())

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = self.window
        self.balance = {asset: float(self.initial_balance) for asset in self.assets}
        self.positions = {asset: 0.0 for asset in self.assets}
        self.equity_curve = []
        self.done = False
        obs = self._get_obs()
        return obs, {}

    def _get_obs(self):
        obs = []
        for asset in self.assets:
            start = self.current_step - self.window
            price_window = self.prices_dict[asset][start:self.current_step]
            local_obs = [*price_window, self.balance[asset], self.positions[asset]]
            for arr in self.predictions_dict.get(asset, {}).values():
                val = arr[self.current_step] if self.current_step < len(arr) else 0.0
                local_obs.append(val if np.isfinite(val) else 0.0)
            obs.extend(local_obs)
        return np.array(obs, dtype=np.float32)

    def step(self, actions):
        total_equity = 0.0
        for i, asset in enumerate(self.assets):
            act = actions[i]
            price = self.prices_dict[asset][self.current_step]
            if act == 1:  # BUY
                if self.balance[asset] > 0:
                    shares = self.balance[asset] / (price * (1 + self.fee))
                    self.positions[asset] += shares
                    self.balance[asset] -= shares * price * (1 + self.fee)
            elif act == 2:  # SELL
                if self.positions[asset] > 0:
                    self.balance[asset] += self.positions[asset] * price * (1 - self.fee)
                    self.positions[asset] = 0.0
            total_equity += self.balance[asset] + self.positions[asset] * price

        self.equity_curve.append(total_equity)

        reward = 0.0
        if len(self.equity_curve) > 1:
            reward = (self.equity_curve[-1] - self.equity_curve[-2]) / (self.equity_curve[-2] + 1e-9)

        self.current_step += 1
        self.done = self.current_step >= self.max_steps
        return self._get_obs(), reward, self.done, False, {}

    def get_metrics(self):
        curve = np.array(self.equity_curve, dtype=np.float32)
        if len(curve) == 0:
            return {}
        final_balance = float(curve[-1])
        total_return = (final_balance - self.initial_balance) / self.initial_balance
        returns = np.diff(curve) / curve[:-1]
        sharpe = np.mean(returns) / (np.std(returns) + 1e-9) if len(returns) > 1 else 0.0
        running_max = np.maximum.accumulate(curve)
        max_dd = float(np.min((curve - running_max)/running_max))
        return {"final_balance": final_balance, "total_return": total_return, "sharpe": sharpe, "max_drawdown": max_dd}

    def get_action_stats(self):
        buys = sum([1 for a in self.equity_curve if a > 0])
        sells = sum([1 for a in self.equity_curve if a < 0])
        return {"buys": buys, "sells": sells}

# %%
# =====================================
# 2️⃣ Загрузка данных по нескольким акциям
# =====================================
tickers = ["MSFT", "AAPL", "TSLA"]

prices_dict_train = {}
prices_dict_test = {}
predictions_train = {}
predictions_test = {}

test_size = 30 * 24
offset = 300
window = 60

for ticker in tickers:
    df = pd.read_csv(f"models/{ticker}/new_data.csv")
    prices = df["Close"].to_numpy()
    preds = {
        "t1": df["predict_t1"].to_numpy(),
        "t3": df["predict_t3"].to_numpy(),
        "t8": df["predict_t8"].to_numpy(),
    }

    prices_dict_train[ticker] = prices[offset:-test_size]
    prices_dict_test[ticker] = prices[-test_size:]

    predictions_train[ticker] = {k: v[offset:-test_size] for k, v in preds.items()}
    predictions_test[ticker] = {k: v[-test_size:] for k, v in preds.items()}

# =====================================
# 3️⃣ Создаём окружения
# =====================================
env_train = MultiAssetTradingEnv(
    prices_dict=prices_dict_train,
    predictions_dict=predictions_train,
    window=window,
    fee=0.000
)
env_test = MultiAssetTradingEnv(
    prices_dict=prices_dict_test,
    predictions_dict=predictions_test,
    window=window,
    fee=0.001
)

check_env(env_train, warn=True)
check_env(env_test, warn=True)

# =====================================
# 4️⃣ Обучение модели
# =====================================
from stable_baselines3 import PPO
model = PPO("MlpPolicy", env_train, verbose=1)


print("🚀 Начинаем обучение мультиактивной модели...")
model.learn(total_timesteps=500_000)
print("✅ Обучение завершено.")

# =====================================
# 5️⃣ Тестирование с онлайн-доподучением
# =====================================
obs, info = env_test.reset()
done = False
step = 0

while not done:
    action, _ = model.predict(obs, deterministic=False)
    next_obs, reward, done, truncated, info = env_test.step(action)

    model.replay_buffer.add(obs, next_obs, action, reward, done, infos=[info])
    model.train(batch_size=64, gradient_steps=1)

    obs = next_obs
    step += 1

    if step % 500 == 0:
        print(f"Онлайн дообучение — шаг {step}")

print("✅ Тест завершён.")

# =====================================
# 6️⃣ Метрики
# =====================================
metrics = env_test.get_metrics()
print("\n=== 📊 TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 🚀 Начинаем обучение мультиактивной модели...
# c:\Users\Данил\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 140  |
# |    iterations      | 1    |
# |    time_elapsed    | 14   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.121       |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012688924 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | -25.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0116     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.0683      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 3           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010663463 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | -5.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00496    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00882    |
# |    value_loss           | 0.0096      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.0833      |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 4           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011869146 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | -1.86       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00581    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.00238     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.152       |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 5           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009007202 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | -3.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00206    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00658    |
# |    value_loss           | 0.00326     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.166      |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 6          |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01313574 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | -4.37      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00821    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00672   |
# |    value_loss           | 0.00197    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.166       |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 7           |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009317847 |
# |    clip_fraction        | 0.0954      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | -2.79       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00687    |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.131       |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 8           |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011337338 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | -5.77       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00943    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00717    |
# |    value_loss           | 0.000734    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4e+03      |
# |    ep_rew_mean          | 0.124        |
# | time/                   |              |
# |    fps                  | 112          |
# |    iterations           | 9            |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0119421715 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.23        |
# |    explained_variance   | -1.25        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00233     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 0.000162     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 10          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013756376 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | -1.28       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0449     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.000972    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 11          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012647409 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | -2.03       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00491    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.000357    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.117       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 12          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010713926 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | -0.732      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0079     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00739    |
# |    value_loss           | 0.000335    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.105       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 13          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011736261 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | -0.361      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0315     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00046     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.105       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 14          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011704824 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | -0.322      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00775    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.000359    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.12        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 15          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011048606 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | -3.32       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00857    |
# |    value_loss           | 0.000816    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 16          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013965955 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | -1.46       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.021      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00837    |
# |    value_loss           | 0.000357    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.123       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 17          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014782983 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | -1          |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00964    |
# |    value_loss           | 0.000211    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.13        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 18          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010605074 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | -0.616      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00808     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00791    |
# |    value_loss           | 0.00034     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.143       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 19          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014198027 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | -0.586      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0368      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.00024     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.138       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 20          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013642265 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | -0.387      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0433     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00665    |
# |    value_loss           | 0.000299    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.138      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 21         |
# |    time_elapsed         | 384        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01230061 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.13      |
# |    explained_variance   | -1.16      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0388    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 0.000421   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.141       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 22          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.015665138 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | -0.118      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0487     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.000214    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.147       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 23          |
# |    time_elapsed         | 421         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009876706 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | -2.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00384     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.000448    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.164       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 24          |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010732641 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | -0.256      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00684     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00925    |
# |    value_loss           | 0.000343    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.163       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 25          |
# |    time_elapsed         | 457         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.015891979 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | -0.448      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0259     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 0.000291    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.161      |
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 26         |
# |    time_elapsed         | 475        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01285818 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | -0.145     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0194     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0115    |
# |    value_loss           | 0.000312   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.161       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 27          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.011503357 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | -0.26       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.016      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.000247    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.16        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 28          |
# |    time_elapsed         | 511         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010878561 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | -0.0721     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00815    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.000293    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.162      |
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 29         |
# |    time_elapsed         | 530        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.01236078 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.03      |
# |    explained_variance   | -0.246     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000854   |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 0.000163   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.157       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 30          |
# |    time_elapsed         | 548         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012530448 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | -1.75       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0292     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00879    |
# |    value_loss           | 0.000341    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 31          |
# |    time_elapsed         | 566         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.013994224 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | -0.172      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0245     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.000228    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.152       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 32          |
# |    time_elapsed         | 584         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013230637 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | -0.743      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 0.000479    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 33          |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010285436 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | -1.07       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0465     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 0.000389    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 34          |
# |    time_elapsed         | 622         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011671151 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | -4.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0204      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00812    |
# |    value_loss           | 0.000284    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.15        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 35          |
# |    time_elapsed         | 641         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012531655 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | -0.236      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0204      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00799    |
# |    value_loss           | 0.000351    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.148      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 36         |
# |    time_elapsed         | 659        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01281856 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | -5.02      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.02      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00729   |
# |    value_loss           | 0.000559   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.144       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 37          |
# |    time_elapsed         | 678         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011504016 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | -1.05       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0333     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.000229    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.138       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 38          |
# |    time_elapsed         | 696         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010751152 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | -0.122      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.000218    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.144       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 39          |
# |    time_elapsed         | 715         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012190744 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | -0.0158     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0443      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.000295    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.144       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 40          |
# |    time_elapsed         | 733         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012501714 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | -1.67       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00923    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00743    |
# |    value_loss           | 0.000347    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.144       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 41          |
# |    time_elapsed         | 752         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.014565529 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | -2.34       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0182     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.000542    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.141       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 42          |
# |    time_elapsed         | 769         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.015006099 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | -1.99       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0174      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.000404    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.157       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 43          |
# |    time_elapsed         | 788         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013400612 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | -2.08       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00958    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00292    |
# |    value_loss           | 0.000482    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.159      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 44         |
# |    time_elapsed         | 806        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01181028 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.9       |
# |    explained_variance   | -0.224     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00668    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00918   |
# |    value_loss           | 0.000409   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.161       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 45          |
# |    time_elapsed         | 824         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009644191 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | -0.967      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00561    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 0.00019     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.4e+03   |
# |    ep_rew_mean          | 0.158     |
# | time/                   |           |
# |    fps                  | 111       |
# |    iterations           | 46        |
# |    time_elapsed         | 842       |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 0.0172835 |
# |    clip_fraction        | 0.164     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.91     |
# |    explained_variance   | -1.01     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0152   |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -0.00894  |
# |    value_loss           | 0.000316  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 47          |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011779364 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | -0.24       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0118      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.00025     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 48          |
# |    time_elapsed         | 879         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.016594578 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | -0.295      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0355      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00805    |
# |    value_loss           | 0.000272    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.15        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 49          |
# |    time_elapsed         | 897         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013383152 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | -0.196      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0095     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 0.000225    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.148       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 50          |
# |    time_elapsed         | 916         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011471411 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | -0.468      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00487     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00407    |
# |    value_loss           | 0.000245    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.147       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 51          |
# |    time_elapsed         | 934         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.010285508 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | -1.86       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00344    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0067     |
# |    value_loss           | 0.000211    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.4e+03   |
# |    ep_rew_mean          | 0.152     |
# | time/                   |           |
# |    fps                  | 111       |
# |    iterations           | 52        |
# |    time_elapsed         | 952       |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.0163996 |
# |    clip_fraction        | 0.209     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.93     |
# |    explained_variance   | -0.24     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0388   |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.0118   |
# |    value_loss           | 0.000174  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4e+03      |
# |    ep_rew_mean          | 0.153        |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 53           |
# |    time_elapsed         | 970          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0117181055 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | -0.112       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0183      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00895     |
# |    value_loss           | 0.000207     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 54          |
# |    time_elapsed         | 988         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.014935853 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | -0.45       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.000344    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.15        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 55          |
# |    time_elapsed         | 1008        |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.012025843 |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0062368084 |
# |    clip_fraction        | 0.0911       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.882       |
# |    explained_variance   | -0.0134      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0135      |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | -0.00525     |
# |    value_loss           | 0.000224     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.202       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 229         |
# |    time_elapsed         | 4202        |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.006761778 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | -0.0284     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.00511    |
# |    value_loss           | 0.000289    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.202       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 230         |
# |    time_elapsed         | 4221        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.013081435 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | -0.0458     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00834     |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00431    |
# |    value_loss           | 0.00026     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.201       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 231         |
# |    time_elapsed         | 4239        |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.015384117 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | -0.0374     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 0.000232    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4e+03      |
# |    ep_rew_mean          | 0.201        |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 232          |
# |    time_elapsed         | 4258         |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0056222826 |
# |    clip_fraction        | 0.0642       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.947       |
# |    explained_variance   | -0.0147      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.02        |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.00455     |
# |    value_loss           | 0.000287     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.2         |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 233         |
# |    time_elapsed         | 4276        |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.005188414 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | -0.00601    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0217     |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.00245    |
# |    value_loss           | 0.000296    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.199       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 234         |
# |    time_elapsed         | 4294        |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.008566225 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.0377     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 0.00033     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.199       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 235         |
# |    time_elapsed         | 4313        |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.008358046 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0684     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0155     |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 0.000276    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4e+03      |
# |    ep_rew_mean          | 0.199        |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 236          |
# |    time_elapsed         | 4331         |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0058891205 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.0102      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00726     |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 0.000287     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.196       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 237         |
# |    time_elapsed         | 4350        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.006255813 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0115     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0031     |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00427    |
# |    value_loss           | 0.000401    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4e+03      |
# |    ep_rew_mean          | 0.196        |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 238          |
# |    time_elapsed         | 4368         |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 0.0029016158 |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.01        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00427     |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | -0.000983    |
# |    value_loss           | 0.000288     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.191       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 239         |
# |    time_elapsed         | 4386        |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.009529276 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | -0.0265     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00931    |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00763    |
# |    value_loss           | 0.000356    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 0.194       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 240         |
# |    time_elapsed         | 4404        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.008427986 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00444    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0194      |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 0.0004      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.196      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 241        |
# |    time_elapsed         | 4422       |
# |    total_timesteps      | 493568     |
# | train/                  |            |
# |    approx_kl            | 0.21324229 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | -0.0146    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0194     |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | 0.0345     |
# |    value_loss           | 0.000463   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.194      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 242        |
# |    time_elapsed         | 4441       |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.18960728 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | -0.0239    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0172     |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | 0.0307     |
# |    value_loss           | 0.000436   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.4e+03   |
# |    ep_rew_mean          | 0.194     |
# | time/                   |           |
# |    fps                  | 111       |
# |    iterations           | 243       |
# |    time_elapsed         | 4459      |
# |    total_timesteps      | 497664    |
# | train/                  |           |
# |    approx_kl            | 0.1069986 |
# |    clip_fraction        | 0.098     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | -0.0397   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00808   |
# |    n_updates            | 2420      |
# |    policy_gradient_loss | 0.015     |
# |    value_loss           | 0.000346  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.191      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 244        |
# |    time_elapsed         | 4478       |
# |    total_timesteps      | 499712     |
# | train/                  |            |
# |    approx_kl            | 0.01778004 |
# |    clip_fraction        | 0.0676     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | -0.0368    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00141    |
# |    n_updates            | 2430       |
# |    policy_gradient_loss | -0.0024    |
# |    value_loss           | 0.000299   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 0.192      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 245        |
# |    time_elapsed         | 4496       |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.10305825 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | -0.0453    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0868     |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | 0.0268     |
# |    value_loss           | 0.000238   |
# ----------------------------------------
# ✅ Обучение завершено.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 71
#      68 action, _ = model.predict(obs, deterministic=False)
#      69 next_obs, reward, done, truncated, info = env_test.step(action)
# ---> 71 model.replay_buffer.add(obs, next_obs, action, reward, done, infos=[info])
#      72 model.train(batch_size=64, gradient_steps=1)
#      74 obs = next_obs
#
# AttributeError: 'PPO' object has no attribute 'replay_buffer'

# %%
obs, info = env_test.reset()
done = False
step = 0

while not done:
    # Получаем действие от обученной модели
    action, _ = model.predict(obs, deterministic=True)  # deterministic=True для стабильного теста
    # Делаем шаг в среде
    obs, reward, done, truncated, info = env_test.step(action)

    step += 1
    if step % 500 == 0:
        print(f"Тест — шаг {step}")

print("✅ Тестирование завершено.")

# =====================================
# 6️⃣ Метрики
# =====================================
metrics = env_test.get_metrics()
print("\n=== 📊 TEST METRICS ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")

# Количество покупок и продаж по каждому активу
print("\n📈 Действия:", env_test.get_action_stats())
# Out:
# Тест — шаг 500
# ✅ Тестирование завершено.
#
# === 📊 TEST METRICS ===
# final_balance: 33394.1719
# total_return: 2.3394
# sharpe: 0.0400
# max_drawdown: -0.0528
#
# 📈 Действия: {'buys': 660, 'sells': 0}
